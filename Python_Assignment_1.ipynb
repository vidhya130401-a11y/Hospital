# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhya130401-a11y/Hospital/blob/main/Python_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## String Concatenation

# %%
Title = "Hello"

# %%
name = input(" Enter your name: Zara")
# Out:
#  Enter your name: ZaraZara

# %%
Output = Title + name

# %%
print(Output)
# Out:
# HelloZara

# %%
Output += " , welcome to python programming"

# %%
print(Output)
# Out:
# HelloZara , welcome to python programming

# %% [markdown]
# ## String Slicing and Indexing

# %%
# a. first charater
print("first charater:", Output[0])
# Out:
# first charater: H

# %%
# b.last charater
print("last charater:", Output[-1])
# Out:
# last charater: g

# %%
# c. first 5 charater
print("first 5 charater:", Output[:5])
# Out:
# first 5 charater: Hello

# %%
# d. last 11 charater
print("last 11 charater:", Output[-11:])
# Out:
# last 11 charater: programming

# %%
# e. string in reverse
print("string in reverse:", Output[::-1])
# Out:
# string in reverse: gnimmargorp nohtyp ot emoclew , araZolleH

# %%
start_index = Output.find("python")

# %%
end_index = start_index + len("phython")

# %%
# f. python existing
# find the satering inedex in "python"
print("Extracted world:", Output[start_index:end_index])
# Out:
# Extracted world: python

# %% [markdown]
# ## String methods

# %%
strM = "Python beginner tutorial"

# %%
# a. uppercase
print("uppercase", strM.upper())
# Out:
# uppercase PYTHON BEGINNER TUTORIAL

# %%
# b. lowercase
print("lowecase", strM.lower())
# Out:
# lowecase python beginner tutorial

# %%
# c. capitalize
print("capitalize", strM.capitalize())
# Out:
# capitalize Python beginner tutorial

# %%
# d. count of 't'
print("count of 't'", strM.count('t'))
# Out:
# count of 't' 3

# %%
from os import replace
# e. replaced "Python" with "Machine Larning"
strM_replaced = strM.replace("Python", "Machine Learning")
print("Python", strM_replaced)
# Out:
# Python Learning beginner tutorial

# %% [markdown]
# ## Tuples

# %%
# two tuple
tuple1 = (10, 20, 30)
tuple2 = (40,50,60)

# %%
# a. Concatenate the two tuple
t_combine = tuple1 + tuple2
print("concatenated tuple:", t_combine)
# Out:
# concatenated tuple: (10, 20, 30, 40, 50, 60)

# %%
# b. repeat element of "t_combine" 3 times
t_combine_repeat = t_combine *3
print("repeated tuple:", t_combine_repeat)
# Out:
# repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# c. access the 3rd elements (index 2)
print("3rd elements:", t_combine[2])
# Out:
# 3rd elements: 30

# %%
# d. first three elemends
print("first 3 elements:", t_combine[:3])
# Out:
# first 3 elements: (10, 20, 30)

# %%
# e. last three elements
print("last 3 elements:", t_combine[-3:])
# Out:
# last 3 elements: (40, 50, 60)
